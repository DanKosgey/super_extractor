# %%
# !pip install matplotlib
# !pip install seaborn
# !pip install tabulate
# Out:
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached kiwisolver-1.4.8-cp313-cp313-win_amd64.whl.metadata (6.3 kB)
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.1 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.1 MB ? eta -:--:--
#    ----- ---------------------------------- 1.0/8.1 MB 1.7 MB/s eta 0:00:05
#    ------- -------------------------------- 1.6/8.1 MB 2.1 MB/s eta 0:00:04
#    --------- ------------------------------ 1.8/8.1 MB 1.8 MB/s eta 0:00:04
#    ---------- ----------------------------- 2.1/8.1 MB 1.9 MB/s eta 0:00:04
#    ------------ --------------------------- 2.6/8.1 MB 1.8 MB/s eta 0:00:04
#    -------------- ------------------------- 2.9/8.1 MB 1.8 MB/s eta 0:00:03
#    --------------- ------------------------ 3.1/8.1 MB 1.8 MB/s eta 0:00:03
#    ------------------ --------------------- 3.7/8.1 MB 1.8 MB/s eta 0:00:03
# ...

# %%
# Import required libraries
import pandas as pd
import numpy as np
import re
from datetime import datetime
import matplotlib.pyplot as plt

# Load the data
# df=pd.read_csv(r"C:\Users\PC\OneDrive\Desktop\python\Gemini extractor\gemini_signal_extractor\data\groups\Sniper Fx signal group\windows.csv")
# Load the combined signals data
# Uncomment the line below if you want to load the combined signals data instead
df = pd.read_csv(r"C:\Users\PC\OneDrive\Desktop\python\gemini_signal_extractor\data\final_signals.csv")

# %%
df
# Out:
#                   window  original_index  \
# 0    𝐆𝐎𝐋𝐃 𝐏𝐄𝐑𝐅𝐄𝐂𝐓 𝐒𝐈𝐆𝐍𝐀𝐋              99
# 1    𝐆𝐎𝐋𝐃 𝐏𝐄𝐑𝐅𝐄𝐂𝐓 𝐒𝐈𝐆𝐍𝐀𝐋             100
# 2    𝐆𝐎𝐋𝐃 𝐏𝐄𝐑𝐅𝐄𝐂𝐓 𝐒𝐈𝐆𝐍𝐀𝐋             101
# 3    𝐆𝐎𝐋𝐃 𝐏𝐄𝐑𝐅𝐄𝐂𝐓 𝐒𝐈𝐆𝐍𝐀𝐋             102
# 4    𝐆𝐎𝐋𝐃 𝐏𝐄𝐑𝐅𝐄𝐂𝐓 𝐒𝐈𝐆𝐍𝐀𝐋             103
# ..                   ...             ...
# 118  𝐆𝐎𝐋𝐃 𝐏𝐄𝐑𝐅𝐄𝐂𝐓 𝐒𝐈𝐆𝐍𝐀𝐋             270
# 119  𝐆𝐎𝐋𝐃 𝐏𝐄𝐑𝐅𝐄𝐂𝐓 𝐒𝐈𝐆𝐍𝐀𝐋             272
# 120  𝐆𝐎𝐋𝐃 𝐏𝐄𝐑𝐅𝐄𝐂𝐓 𝐒𝐈𝐆𝐍𝐀𝐋             273
# 121  𝐆𝐎𝐋𝐃 𝐏𝐄𝐑𝐅𝐄𝐂𝐓 𝐒𝐈𝐆𝐍𝐀𝐋             274
# 122  𝐆𝐎𝐋𝐃 𝐏𝐄𝐑𝐅𝐄𝐂𝐓 𝐒𝐈𝐆𝐍𝐀𝐋             275
#
#                                          combined_text direction  entry_price  \
# 0    XAUUSD BUY 1930\n\nTP. 1934\nTP. 1936\nTP. 194...       BUY    1930.0000
# 1    XAUUSD BUY 1925\n\nTP. 1929\nTP. 1933\nTP. 193...       BUY    1925.0000
# 2    GBPUSD BUY 1.27100\n\nTP 1.27300\nTP 1.27600\n...       BUY       1.2710
# 3    GBPNZD SELL 2.10000\n\nTP 2.09800\nTP 2.09500\...      SELL       2.1000
# ...

# %%
for i in df['combined_text']:
    print(df['direction'])
    print(i+'\n\n\n'+'...........')
# Out:
# 0       BUY
# 1       BUY
# 2       BUY
# 3      SELL
# 4      SELL
#        ...
# 118    SELL
# 119    SELL
# 120    SELL
# 121     BUY
# 122     BUY
# Name: direction, Length: 123, dtype: object
# XAUUSD BUY 1930
#
# TP. 1934
# TP. 1936
# TP. 1940
# TP. 1944
# SL. 1918
#
#
# ...........
# 0       BUY
# 1       BUY
# 2       BUY
# 3      SELL
# 4      SELL
#        ...
# 118    SELL
# 119    SELL
# 120    SELL
# 121     BUY
# 122     BUY
# Name: direction, Length: 123, dtype: object
# XAUUSD BUY 1925
#
# TP. 1929
# TP. 1933
# TP. 1937
# TP. 1941
# SL. 1912
#
#
# ...........
# 0       BUY
# 1       BUY
# 2       BUY
# 3      SELL
# 4      SELL
#        ...
# 118    SELL
# 119    SELL
# 120    SELL
# 121     BUY
# 122     BUY
# Name: direction, Length: 123, dtype: object
# GBPUSD BUY 1.27100
#
# TP 1.27300
# TP 1.27600
# TP 1.27800
# SL 1.26500
#
#
# ...........
# 0       BUY
# 1       BUY
# 2       BUY
# 3      SELL
# 4      SELL
#        ...
# 118    SELL
# 119    SELL
# ...

# %%
# Basic data inspection
print(f"Total rows: {len(df)}")
print(f"Columns: {df.columns.tolist()}")
print("\nSample data:")
print(df.head().to_markdown())
# Out:
# Total rows: 123
# Columns: ['window', 'original_index', 'combined_text', 'direction', 'entry_price', 'entry_zone', 'sl', 'tp1', 'tp2', 'tp3', 'tp4', 'notes', 'confidence', 'processed_at']
#
# Sample data:
# |    | window              |   original_index | combined_text       | direction   |   entry_price |   entry_zone |       sl |      tp1 |      tp2 |      tp3 |   tp4 |   notes | confidence   | processed_at               |
# |---:|:--------------------|-----------------:|:--------------------|:------------|--------------:|-------------:|---------:|---------:|---------:|---------:|------:|--------:|:-------------|:---------------------------|
# |  0 | 𝐆𝐎𝐋𝐃 𝐏𝐄𝐑𝐅𝐄𝐂𝐓 𝐒𝐈𝐆𝐍𝐀𝐋 |               99 | XAUUSD BUY 1930     | BUY         |      1930     |          nan | 1918     | 1934     | 1936     | 1940     |  1944 |     nan | high         | 2025-06-22T21:54:14.142521 |
# ...

# %%
# Missing values analysis
missing_values = df.isnull().sum()
print("\nMissing values per column:")
print(missing_values[missing_values > 0])

# Duplicate detection
duplicates = df.duplicated(subset=['combined_text', 'symbol', 'direction']).sum()
print(f"\nPotential duplicates: {duplicates}")
# Out:
# Missing values per column:
# entry_price     3
# entry_zone     32
# tp3            14
# tp4            28
# notes          27
# dtype: int64
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13568\3512212116.py in ?()
#       3 print("\nMissing values per column:")
#       4 print(missing_values[missing_values > 0])
#       5
#       6 # Duplicate detection
# ----> 7 duplicates = df.duplicated(subset=['combined_text', 'symbol', 'direction']).sum()
#       8 print(f"\nPotential duplicates: {duplicates}")
#
# c:\Users\PC\OneDrive\Desktop\python\Gemini extractor\.venv\Lib\site-packages\pandas\core\frame.py in ?(self, subset, keep)
#    6953         # Otherwise, raise a KeyError, same as if you try to __getitem__ with a
#    6954         # key that doesn't exist.
#    6955         diff = set(subset) - set(self.columns)
#    6956         if diff:
# ...
